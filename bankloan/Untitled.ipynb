# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style='whitegrid')
pd.set_option('display.max_columns',None)

# %%
file = open('Columns.txt', 'r')
text = file.read()
text
# Out:
# 'Gender\nAge\nDebt\t\nMarried\t\nBankCustomer\t\nEducationLevel\t\nEthnicity\t\nYearsEmployed\t\nPriorDefault\t\nEmployed\t\nCreditScore\t\nDriversLicense\t\nCitizen\t\nZipCode\t\nIncome\t\nApproved\n'

# %%
Columns = text.split('\n')

# %%
Columns
# Out:
# ['Gender',
#  'Age',
#  'Debt\t',
#  'Married\t',
#  'BankCustomer\t',
#  'EducationLevel\t',
#  'Ethnicity\t',
#  'YearsEmployed\t',
#  'PriorDefault\t',
#  'Employed\t',
#  'CreditScore\t',
#  'DriversLicense\t',
#  'Citizen\t',
#  'ZipCode\t',
#  'Income\t',
#  'Approved',
#  '']

# %%
Columns = Columns[:-1]
Columns
# Out:
# ['Gender',
#  'Age',
#  'Debt\t',
#  'Married\t',
#  'BankCustomer\t',
#  'EducationLevel\t',
#  'Ethnicity\t',
#  'YearsEmployed\t',
#  'PriorDefault\t',
#  'Employed\t',
#  'CreditScore\t',
#  'DriversLicense\t',
#  'Citizen\t',
#  'ZipCode\t',
#  'Income\t',
#  'Approved']

# %%
Columns = [str(i).strip('\t') for i in Columns]
Columns
# Out:
# ['Gender',
#  'Age',
#  'Debt',
#  'Married',
#  'BankCustomer',
#  'EducationLevel',
#  'Ethnicity',
#  'YearsEmployed',
#  'PriorDefault',
#  'Employed',
#  'CreditScore',
#  'DriversLicense',
#  'Citizen',
#  'ZipCode',
#  'Income',
#  'Approved']

# %%
data = pd.read_csv('cc_approvals.data', names=Columns)
data.head()
# Out:
#   Gender    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0      b  30.83  0.000       u            g              w         v
# 1      a  58.67  4.460       u            g              q         h
# 2      a  24.50  0.500       u            g              q         h
# 3      b  27.83  1.540       u            g              w         v
# 4      b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#   ZipCode  Income Approved
# 0   00202       0        +
# 1   00043     560        +
# 2   00280     824        +
# 3   00100       3        +
# 4   00120       0        +

# %%
data.shape
# Out:
# (690, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    object
#  1   Age             690 non-null    object
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    object
#  4   BankCustomer    690 non-null    object
#  5   EducationLevel  690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    object
#  9   Employed        690 non-null    object
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    object
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    object
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86
#        '38.42', '26.58', '35.00', '29.42', '49.17', '51.83', '58.58',
#        '53.33', '27.17', '25.92', '30.58', '17.25', '27.33', '36.50',
#        '29.75', '52.42', '36.17', '34.58', '21.92', '36.58', '31.08',
#        '30.42', '21.08', '17.42', '39.17', '26.50', '17.33', '23.75',
#        '34.67', '74.83', '45.33', '47.25', '24.17', '39.25', '39.00',
#        '64.08', '31.33', '21.00', '13.75', '46.00', '20.25', '60.92',
#        '30.00', '22.83', '45.17', '41.58', '55.75', '25.33', '31.83',
#        '33.92', '24.92', '80.25', '30.08', '48.33', '76.75', '51.33',
#        '41.92', '29.58', '32.17', '51.42', '42.17', '43.08', '59.50',
#        '65.17', '20.33', '48.50', '28.08', '73.42', '51.58', '38.67',
#        '46.08', '20.08', '42.25', '16.17', '47.83', '22.00', '38.33',
#        '25.58', '21.58', '36.08', '38.75', '35.58', '31.58', '15.75',
#        '17.92', '30.33', '47.17', '25.83', '50.25', '36.42'], dtype=object)

# %%
for index, j in enumerate(data['Age'].tolist()):
    if '?' in j:
        print(index)
# Out:
# 83
# 86
# 92
# 97
# 254
# 286
# 329
# 445
# 450
# 500
# 515
# 608

# %%
data.iloc[83,:]
# Out:
# Gender                a
# Age                   ?
# Debt                3.5
# Married               u
# BankCustomer          g
# EducationLevel        d
# Ethnicity             v
# YearsEmployed       3.0
# PriorDefault          t
# Employed              f
# CreditScore           0
# DriversLicense        t
# Citizen               g
# ZipCode           00300
# Income                0
# Approved              -
# Name: 83, dtype: object

# %%
data['Married'].unique()
# Out:
# array(['u', 'y', '?', 'l'], dtype=object)

# %%
WrongValueColumns = []
for col in data.columns : 
    if data[col].tolist().count('?') > 0 : 
        print(f" at Column {col} # of ? is {data[col].tolist().count('?')}")        
        WrongValueColumns.append(col)
# Out:
#  at Column Gender # of ? is 12
#  at Column Age # of ? is 12
#  at Column Married # of ? is 6
#  at Column BankCustomer # of ? is 6
#  at Column EducationLevel # of ? is 9
#  at Column Ethnicity # of ? is 9
#  at Column ZipCode # of ? is 13

# %%
data.drop(data[data['Married']=='?'].index,axis = 0,inplace=True)
data.reset_index(inplace=True)
data.drop(['index'],axis = 1,inplace=True)
data.head()
# Out:
#   Gender    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0      b  30.83  0.000       u            g              w         v
# 1      a  58.67  4.460       u            g              q         h
# 2      a  24.50  0.500       u            g              q         h
# 3      b  27.83  1.540       u            g              w         v
# 4      b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#   ZipCode  Income Approved
# 0   00202       0        +
# 1   00043     560        +
# 2   00280     824        +
# 3   00100       3        +
# 4   00120       0        +

# %%
for col in data.columns : 
    if data[col].tolist().count('?') > 0 : 
        print(f" at Column {col} # of ? is {data[col].tolist().count('?')}")
# Out:
#  at Column Gender # of ? is 12
#  at Column Age # of ? is 12
#  at Column EducationLevel # of ? is 3
#  at Column Ethnicity # of ? is 3
#  at Column ZipCode # of ? is 7

# %%
data.drop(data[data['Gender']=='?'].index,axis = 0,inplace=True)
data.reset_index(inplace=True)
data.drop(['index'],axis = 1,inplace=True)
data
# Out:
#     Gender    Age    Debt Married BankCustomer EducationLevel Ethnicity  \
# 0        b  30.83   0.000       u            g              w         v
# 1        a  58.67   4.460       u            g              q         h
# 2        a  24.50   0.500       u            g              q         h
# 3        b  27.83   1.540       u            g              w         v
# 4        b  20.17   5.625       u            g              w         v
# ..     ...    ...     ...     ...          ...            ...       ...
# 667      b  21.08  10.085       y            p              e         h
# 668      a  22.67   0.750       u            g              c         v
# 669      a  25.25  13.500       y            p             ff        ff
# 670      b  17.92   0.205       u            g             aa         v
# 671      b  35.00   3.375       u            g              c         h
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0             1.25            t        t            1              f       g
# 1             3.04            t        t            6              f       g
# 2             1.50            t        f            0              f       g
# 3             3.75            t        t            5              t       g
# 4             1.71            t        f            0              f       s
# ..             ...          ...      ...          ...            ...     ...
# 667           1.25            f        f            0              f       g
# 668           2.00            f        t            2              t       g
# 669           2.00            f        t            1              t       g
# 670           0.04            f        f            0              f       g
# 671           8.29            f        f            0              t       g
#
#     ZipCode  Income Approved
# 0     00202       0        +
# 1     00043     560        +
# 2     00280     824        +
# 3     00100       3        +
# 4     00120       0        +
# ..      ...     ...      ...
# 667   00260       0        -
# 668   00200     394        -
# 669   00200       1        -
# 670   00280     750        -
# 671   00000       0        -
#
# [672 rows x 16 columns]

# %%
for col in data.columns : 
    if data[col].tolist().count('?') > 0 : 
        print(f" at Column {col} # of ? is {data[col].tolist().count('?')}")
# Out:
#  at Column Age # of ? is 12
#  at Column EducationLevel # of ? is 1
#  at Column Ethnicity # of ? is 1
#  at Column ZipCode # of ? is 7

# %%
data['Age'].replace('?',35.0,inplace=True)

# %%
for col in data.columns : 
    if data[col].tolist().count('?') > 0 : 
        print(f" at Column {col} # of ? is {data[col].tolist().count('?')}")
# Out:
#  at Column EducationLevel # of ? is 1
#  at Column Ethnicity # of ? is 1
#  at Column ZipCode # of ? is 7

# %%
data['EducationLevel'].mode()
# Out:
# 0    c
# Name: EducationLevel, dtype: object

# %%
data['EducationLevel'].replace('?','c',inplace=True)

# %%
data['Ethnicity'].mode()
# Out:
# 0    v
# Name: Ethnicity, dtype: object

# %%
data['Ethnicity'].replace('?','v',inplace=True)

# %%
for col in data.columns : 
    if data[col].tolist().count('?') > 0 : 
        print(f" at Column {col} # of ? is {data[col].tolist().count('?')}")
# Out:
#  at Column ZipCode # of ? is 7

# %%
data.drop(data[data['ZipCode']=='?'].index,axis = 0,inplace=True)
data.reset_index(inplace=True)
data.drop(['index'],axis = 1,inplace=True)
data
# Out:
#     Gender    Age    Debt Married BankCustomer EducationLevel Ethnicity  \
# 0        b  30.83   0.000       u            g              w         v
# 1        a  58.67   4.460       u            g              q         h
# 2        a  24.50   0.500       u            g              q         h
# 3        b  27.83   1.540       u            g              w         v
# 4        b  20.17   5.625       u            g              w         v
# ..     ...    ...     ...     ...          ...            ...       ...
# 660      b  21.08  10.085       y            p              e         h
# 661      a  22.67   0.750       u            g              c         v
# 662      a  25.25  13.500       y            p             ff        ff
# 663      b  17.92   0.205       u            g             aa         v
# 664      b  35.00   3.375       u            g              c         h
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0             1.25            t        t            1              f       g
# 1             3.04            t        t            6              f       g
# 2             1.50            t        f            0              f       g
# 3             3.75            t        t            5              t       g
# 4             1.71            t        f            0              f       s
# ..             ...          ...      ...          ...            ...     ...
# 660           1.25            f        f            0              f       g
# 661           2.00            f        t            2              t       g
# 662           2.00            f        t            1              t       g
# 663           0.04            f        f            0              f       g
# 664           8.29            f        f            0              t       g
#
#     ZipCode  Income Approved
# 0     00202       0        +
# 1     00043     560        +
# 2     00280     824        +
# 3     00100       3        +
# 4     00120       0        +
# ..      ...     ...      ...
# 660   00260       0        -
# 661   00200     394        -
# 662   00200       1        -
# 663   00280     750        -
# 664   00000       0        -
#
# [665 rows x 16 columns]

# %%
for col in data.columns : 
    if data[col].tolist().count('?') > 0 : 
        print(f" at Column {col} # of ? is {data[col].tolist().count('?')}")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          665 non-null    object
#  1   Age             665 non-null    object
#  2   Debt            665 non-null    float64
#  3   Married         665 non-null    object
#  4   BankCustomer    665 non-null    object
#  5   EducationLevel  665 non-null    object
#  6   Ethnicity       665 non-null    object
#  7   YearsEmployed   665 non-null    float64
#  8   PriorDefault    665 non-null    object
#  9   Employed        665 non-null    object
#  10  CreditScore     665 non-null    int64
#  11  DriversLicense  665 non-null    object
#  12  Citizen         665 non-null    object
#  13  ZipCode         665 non-null    object
#  14  Income          665 non-null    int64
#  15  Approved        665 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 83.2+ KB

# %%
data['Age'] = data['Age'].astype(float)

# %%
data[data['Age'] < 18]
# Out:
#     Gender    Age    Debt Married BankCustomer EducationLevel Ethnicity  \
# 25       a  15.83   0.585       u            g              c         h
# 219      a  17.58   9.000       u            g             aa         v
# 247      a  17.83  11.000       u            g              x         h
# 260      b  17.08   0.085       y            p              c         v
# 272      b  16.25   0.835       u            g              m         v
# 275      b  17.67   4.460       u            g              c         v
# 276      a  16.50   1.250       u            g              q         v
# 278      b  17.58  10.000       u            g              w         h
# 287      a  16.08   0.335       u            g             ff        ff
# 291      b  16.33   2.750       u            g             aa         v
# 296      a  15.92   2.875       u            g              q         v
# 305      a  16.33   0.210       u            g             aa         v
# 307      b  16.25   0.000       y            p             aa         v
# 310      b  17.50  22.000       l           gg             ff         o
# 345      a  16.00   0.165       u            g             aa         v
# 353      b  16.92   0.335       y            p              k         v
# 379      b  15.17   7.000       u            g              e         v
# 396      b  16.00   3.125       u            g              w         v
# 397      b  17.08   0.250       u            g              q         v
# 431      b  17.25   3.000       u            g              k         v
# 432      a  17.67   0.000       y            p              j        ff
# 433      b  16.50   0.125       u            g              c         v
# 454      b  16.33   4.085       u            g              i         h
# 457      b  17.42   6.500       u            g              i         v
# 464      a  16.92   0.500       u            g              i         v
# 466      a  17.33   9.500       u            g             aa         v
# 493      b  13.75   4.000       y            p              w         v
# 500      b  16.08   0.750       u            g              c         v
# 585      b  16.17   0.040       u            g              c         v
# 627      a  15.83   7.625       u            g              q         v
# 634      a  15.75   0.375       u            g              c         v
# 643      a  17.92   0.540       u            g              c         v
# 653      a  17.92  10.210       u            g             ff        ff
# 657      b  17.08   3.290       u            g              i         v
# 663      b  17.92   0.205       u            g             aa         v
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 25           1.500            t        t            2              f       g
# 219          1.375            t        f            0              t       g
# 247          1.000            t        t           11              f       g
# 260          0.040            f        f            0              f       g
# 272          0.085            t        f            0              f       s
# 275          0.250            f        f            0              f       s
# 276          0.250            f        t            1              f       g
# 278          0.165            f        t            1              f       g
# 287          0.000            f        t            1              f       g
# 291          0.665            f        t            1              f       g
# 296          0.085            f        f            0              f       g
# 305          0.125            f        f            0              f       g
# 307          0.250            f        f            0              f       g
# 310          0.000            f        f            0              t       p
# 345          1.000            f        t            2              t       g
# 353          0.290            f        f            0              f       s
# 379          1.000            f        f            0              f       g
# 396          0.085            f        t            1              f       g
# 397          0.335            f        t            4              f       g
# 431          0.040            f        f            0              t       g
# 432          0.000            f        f            0              f       g
# 433          0.165            f        f            0              f       g
# 454          0.415            f        f            0              t       g
# 457          0.125            f        f            0              f       g
# 464          0.165            f        t            6              t       g
# 466          1.750            f        t           10              t       g
# 493          1.750            t        t            2              t       g
# 500          1.750            t        t            5              t       g
# 585          0.040            f        f            0              f       g
# 627          0.125            f        t            1              t       g
# 634          1.000            f        f            0              f       g
# 643          1.750            f        t            1              t       g
# 653          0.000            f        f            0              f       g
# 657          0.335            f        f            0              t       g
# 663          0.040            f        f            0              f       g
#
#     ZipCode  Income Approved
# 25    00100       0        +
# 219   00000       0        +
# 247   00000    3000        +
# 260   00140     722        -
# 272   00200       0        -
# 275   00080       0        -
# 276   00108      98        -
# 278   00120       1        -
# 287   00160     126        -
# 291   00080      21        -
# 296   00120       0        -
# 305   00200       1        -
# 307   00060       0        -
# 310   00450  100000        +
# 345   00320       1        -
# 353   00200       0        -
# 379   00600       0        -
# 396   00000       6        -
# 397   00160       8        -
# 431   00160      40        -
# 432   00086       0        -
# 433   00132       0        -
# 454   00120       0        -
# 457   00060     100        -
# 464   00240      35        -
# 466   00000      10        -
# 493   00120    1000        +
# 500   00352     690        +
# 585   00000       0        +
# 627   00000     160        -
# 634   00120      18        -
# 643   00080       5        -
# 653   00000      50        -
# 657   00140       2        -
# 663   00280     750        -

# %%
def Level(x,Values,Names) : #[18,22,40,81] , [Teen,YoungMan,Adult,Old]
    x = float(x)
    for a,b in zip(Values,Names) : 
        if x < a : return b
data['AgeLevel']  = data['Age'].apply(lambda x : Level(x,[18,22,40,81] , ['Teen','YoungMan','Adult','Old']))
data['AgeLevel'].value_counts()
# Out:
# Adult       385
# Old         138
# YoungMan    107
# Teen         35
# Name: AgeLevel, dtype: int64

# %%
data['DebtLevel']  = data['Debt'].apply(lambda x : Level(x,[5,15,30] , ['Poor Debt','Medium Debt','Good Debt']))
data['DebtLevel'].value_counts()
# Out:
# Poor Debt      426
# Medium Debt    210
# Good Debt       29
# Name: DebtLevel, dtype: int64

# %%
data['YearsEmployedLevel']  = data['YearsEmployed'].apply(lambda x : Level(x,[1,5,30],['Low Experience','Medium Experience','Good Experience']))
data['YearsEmployedLevel'].value_counts()
# Out:
# Low Experience       314
# Medium Experience    250
# Good Experience      101
# Name: YearsEmployedLevel, dtype: int64

# %%
data['CreditScoreLevel']  = data['CreditScore'].apply(lambda x : Level(x,[3,7,70], ['Poor Credit','Medium Credit','Good Credit']))
data['CreditScoreLevel'].value_counts()
# Out:
# Poor Credit      488
# Good Credit       95
# Medium Credit     82
# Name: CreditScoreLevel, dtype: int64

# %%
data['IncomeLevel']  = data['Income'].apply(lambda x : Level(x,[300,1000,100001], ['Poor Income','Medium Income','Good Income']))
data['IncomeLevel'].value_counts()
# Out:
# Poor Income      474
# Good Income      109
# Medium Income     82
# Name: IncomeLevel, dtype: int64

# %%
data['TotalSavings'] = data.apply(lambda x : x['YearsEmployed']*x['Income']*3,axis=1)
data['TotalSavings'].min(),data['TotalSavings'].max()

data['TotalSavingsLevel'] = data['TotalSavings'].apply(lambda x : Level(x,[100,10000,100000,1000000],
                                                                        ['No Savings','Low Savings','Medium Savings','Good Savings']))

data['TotalSavingsLevel'].value_counts()
# Out:
# No Savings        427
# Low Savings       171
# Medium Savings     54
# Good Savings       13
# Name: TotalSavingsLevel, dtype: int64

# %%
ZipSet = set([str(i)[:3] for i in data['ZipCode'].unique()])
ZipSet
# Out:
# {'000', '001', '002', '003', '004', '005', '006', '007', '008', '009', '020'}

# %%
Areas = {k:v for v,k in zip([f'Area {i+1}' for i in range(len(ZipSet))],
                    ZipSet)}
Areas
# Out:
# {'005': 'Area 1',
#  '000': 'Area 2',
#  '004': 'Area 3',
#  '020': 'Area 4',
#  '003': 'Area 5',
#  '006': 'Area 6',
#  '001': 'Area 7',
#  '002': 'Area 8',
#  '009': 'Area 9',
#  '008': 'Area 10',
#  '007': 'Area 11'}

# %%
data['ZipArea'] = data['ZipCode'].apply(lambda x : Areas[str(x)[:3]])
data['ZipArea'].value_counts()
# Out:
# Area 2     210
# Area 7     189
# Area 8     127
# Area 5      75
# Area 3      39
# Area 1      14
# Area 11      4
# Area 6       3
# Area 9       2
# Area 4       1
# Area 10      1
# Name: ZipArea, dtype: int64

# %%
data[data['ZipArea']=='Area 3']['ZipCode'].unique()
# Out:
# array(['00434', '00455', '00491', '00400', '00420', '00443', '00410',
#        '00408', '00440', '00431', '00487', '00470', '00450', '00411',
#        '00460', '00480', '00454', '00422', '00432', '00416', '00465'],
#       dtype=object)

# %%
def CPlot(feature) : 
    global data
    fig, ax = plt.subplots(figsize=(10,6))
    sns.countplot(x=feature, data=data,facecolor=(0, 0, 0, 0),
                  linewidth=5,edgecolor=sns.color_palette("dark", 3))
    ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)

def KPlot(feature,Limit=0) : 
    global data
    fig, ax = plt.subplots(figsize=(10,6))
    if Limit == 0 : 
        sns.kdeplot(data[feature], shade=True)
    else : 
        Data = data[data[feature]<=Limit]
        sns.kdeplot(Data[feature], shade=True)
def BPlot(feature1,feature2 = None,hue = None) : 
    global data
    fig, ax = plt.subplots(figsize=(10,6))
    if feature2 ==  None and hue == None : 
        sns.boxplot(data[feature1],width=0.3,color='r')
    elif  feature2 !=  None and hue == None :
        sns.boxplot(x = data[feature1],y=data[feature2],width=0.3,color='r')
    elif  feature2 !=  None and hue != None :
        sns.boxplot(x = data[feature1],y=data[feature2],hue=data[hue],width=0.3,color='r')
        
def JPlot(feature1,feature2,Type = 'scatter') : 
    global data
    sns.jointplot(data=data, x=feature1, y=feature2, kind=Type)   
    
    
def Pie(feature,Limit=20) : 
    global data
    fig, ax = plt.subplots(figsize=(10,6))
    plt.pie(data[feature].value_counts()[:Limit],labels=list(
        data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,
            explode = [0.05 for i in range(len(data[feature].value_counts()[:Limit]))] )
    plt.show()     
    
def SelectedGenderPie(feature,Limit=10) : 
    global data
    fig, ax = plt.subplots(figsize=(15,4))
    
    plt.subplot(1,2,1)
    plt.title('Gender A')
    Data = data[data['Gender']=='a']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(
        Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,
            explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )
  
    plt.subplot(1,2,2)
    plt.title('Gender B')
    Data = data[data['Gender']=='b']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(
        Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )
    plt.show()        
    
def SelectedApprovedPie(feature,Limit=10) : 
    global data
    fig, ax = plt.subplots(figsize=(15,4))
    
    plt.subplot(1,2,1)
    plt.title('Approved')
    Data = data[data['Approved']=='+']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(
        Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,
            explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )
  
    plt.subplot(1,2,2)
    plt.title('Not Approved')
    Data = data[data['Approved']=='-']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(
        Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )
    plt.show()        
    
def SelectedAgePie(feature,Limit=10) : 
    global data
    fig, ax = plt.subplots(figsize=(15,4))
    
    plt.subplot(1,4,1)
    plt.title('Teen')
    Data = data[data['AgeLevel']=='Teen']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(
        Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,
            explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )
  
    plt.subplot(1,4,2)
    plt.title('YoungMan')
    Data = data[data['AgeLevel']=='YoungMan']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(
        Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )

    plt.subplot(1,4,3)
    plt.title('Adult')
    Data = data[data['AgeLevel']=='Adult']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )

    plt.subplot(1,4,4)
    plt.title('Old')
    Data = data[data['AgeLevel']=='Old']
    plt.pie(Data[feature].value_counts()[:Limit],labels=list(Data[feature].value_counts()[:Limit].index),
        autopct ='%1.2f%%' , labeldistance = 1.1,explode = [0.05 for i in range(len(Data[feature].value_counts()[:Limit]))] )

    plt.show()

# %%
Pie('Approved')

# %%
Pie('Gender')

# %%
KPlot('Age')

# %%
CPlot('AgeLevel')

# %%
SelectedApprovedPie('AgeLevel')

# %%
KPlot('Debt')

# %%
Pie('DebtLevel')

# %%
SelectedApprovedPie('DebtLevel')

# %%
SelectedAgePie('DebtLevel')

# %%
BPlot('Age')
# Out:
# C:\Users\abdal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
BPlot('Debt')
# Out:
# C:\Users\abdal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
JPlot('YearsEmployed','Debt','kde')

# %%
JPlot('Age','CreditScore')

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Debt', 'Married', 'BankCustomer', 'EducationLevel',
#        'Ethnicity', 'YearsEmployed', 'PriorDefault', 'Employed', 'CreditScore',
#        'DriversLicense', 'Citizen', 'ZipCode', 'Income', 'Approved',
#        'AgeLevel', 'DebtLevel', 'YearsEmployedLevel', 'CreditScoreLevel',
#        'IncomeLevel', 'TotalSavings', 'TotalSavingsLevel', 'ZipArea'],
#       dtype='object')

# %%
EncodedFeatures = ['Gender','Married','BankCustomer','EducationLevel',
                   'Ethnicity','PriorDefault','Employed','DriversLicense',
                   'Citizen','ZipCode','Approved','AgeLevel','DebtLevel','YearsEmployedLevel',
                   'CreditScoreLevel','IncomeLevel','TotalSavingsLevel','ZipArea']
data[EncodedFeatures]
# Out:
#     Gender Married BankCustomer EducationLevel Ethnicity PriorDefault  \
# 0        b       u            g              w         v            t
# 1        a       u            g              q         h            t
# 2        a       u            g              q         h            t
# 3        b       u            g              w         v            t
# 4        b       u            g              w         v            t
# ..     ...     ...          ...            ...       ...          ...
# 660      b       y            p              e         h            f
# 661      a       u            g              c         v            f
# 662      a       y            p             ff        ff            f
# 663      b       u            g             aa         v            f
# 664      b       u            g              c         h            f
#
#     Employed DriversLicense Citizen ZipCode Approved  AgeLevel    DebtLevel  \
# 0          t              f       g   00202        +     Adult    Poor Debt
# 1          t              f       g   00043        +       Old    Poor Debt
# 2          f              f       g   00280        +     Adult    Poor Debt
# 3          t              t       g   00100        +     Adult    Poor Debt
# 4          f              f       s   00120        +  YoungMan  Medium Debt
# ..       ...            ...     ...     ...      ...       ...          ...
# 660        f              f       g   00260        -  YoungMan  Medium Debt
# 661        t              t       g   00200        -     Adult    Poor Debt
# 662        t              t       g   00200        -     Adult  Medium Debt
# 663        f              f       g   00280        -      Teen    Poor Debt
# 664        f              t       g   00000        -     Adult    Poor Debt
#
#     YearsEmployedLevel CreditScoreLevel    IncomeLevel TotalSavingsLevel  \
# 0    Medium Experience      Poor Credit    Poor Income        No Savings
# 1    Medium Experience    Medium Credit  Medium Income       Low Savings
# 2    Medium Experience      Poor Credit  Medium Income       Low Savings
# 3    Medium Experience    Medium Credit    Poor Income        No Savings
# 4    Medium Experience      Poor Credit    Poor Income        No Savings
# ..                 ...              ...            ...               ...
# 660  Medium Experience      Poor Credit    Poor Income        No Savings
# 661  Medium Experience      Poor Credit  Medium Income       Low Savings
# 662  Medium Experience      Poor Credit    Poor Income        No Savings
# 663     Low Experience      Poor Credit  Medium Income        No Savings
# 664    Good Experience      Poor Credit    Poor Income        No Savings
#
#     ZipArea
# 0    Area 8
# 1    Area 2
# 2    Area 8
# 3    Area 7
# 4    Area 7
# ..      ...
# 660  Area 8
# 661  Area 8
# 662  Area 8
# 663  Area 8
# 664  Area 2
#
# [665 rows x 18 columns]

# %%
from sklearn.preprocessing import LabelEncoder

def ApplyEncoder(OriginalColumn) : 
    global data
    Encoder = LabelEncoder()
    Encoder.fit(data[OriginalColumn])
    return Encoder.transform(data[OriginalColumn])

# %%
for col in EncodedFeatures : 
    data[f'Enc_{col}'] = ApplyEncoder(col)
data.head()
# Out:
#   Gender    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0      b  30.83  0.000       u            g              w         v
# 1      a  58.67  4.460       u            g              q         h
# 2      a  24.50  0.500       u            g              q         h
# 3      b  27.83  1.540       u            g              w         v
# 4      b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#   ZipCode  Income Approved  AgeLevel    DebtLevel YearsEmployedLevel  \
# 0   00202       0        +     Adult    Poor Debt  Medium Experience
# 1   00043     560        +       Old    Poor Debt  Medium Experience
# 2   00280     824        +     Adult    Poor Debt  Medium Experience
# 3   00100       3        +     Adult    Poor Debt  Medium Experience
# 4   00120       0        +  YoungMan  Medium Debt  Medium Experience
#
#   CreditScoreLevel    IncomeLevel  TotalSavings TotalSavingsLevel ZipArea  \
# 0      Poor Credit    Poor Income          0.00        No Savings  Area 8
# 1    Medium Credit  Medium Income       5107.20       Low Savings  Area 2
# 2      Poor Credit  Medium Income       3708.00       Low Savings  Area 8
# 3    Medium Credit    Poor Income         33.75        No Savings  Area 7
# 4      Poor Credit    Poor Income          0.00        No Savings  Area 7
#
#    Enc_Gender  Enc_Married  Enc_BankCustomer  Enc_EducationLevel  \
# 0           1            1                 0                  12
# 1           0            1                 0                  10
# 2           0            1                 0                  10
# 3           1            1                 0                  12
# 4           1            1                 0                  12
#
#    Enc_Ethnicity  Enc_PriorDefault  Enc_Employed  Enc_DriversLicense  \
# 0              7                 1             1                   0
# 1              3                 1             1                   0
# 2              3                 1             0                   0
# 3              7                 1             1                   1
# 4              7                 1             0                   0
#
#    Enc_Citizen  Enc_ZipCode  Enc_Approved  Enc_AgeLevel  Enc_DebtLevel  \
# 0            0           68             0             0              2
# 1            0           11             0             1              2
# 2            0           94             0             0              2
# 3            0           31             0             0              2
# 4            2           37             0             3              1
#
#    Enc_YearsEmployedLevel  Enc_CreditScoreLevel  Enc_IncomeLevel  \
# 0                       2                     2                2
# 1                       2                     1                1
# 2                       2                     2                1
# 3                       2                     1                2
# 4                       2                     2                2
#
#    Enc_TotalSavingsLevel  Enc_ZipArea
# 0                      3            9
# 1                      1            3
# 2                      1            9
# 3                      3            8
# 4                      3            8

# %%
data[['Approved','Enc_Approved']]
# Out:
#     Approved  Enc_Approved
# 0          +             0
# 1          +             0
# 2          +             0
# 3          +             0
# 4          +             0
# ..       ...           ...
# 660        -             1
# 661        -             1
# 662        -             1
# 663        -             1
# 664        -             1
#
# [665 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Debt', 'Married', 'BankCustomer', 'EducationLevel',
#        'Ethnicity', 'YearsEmployed', 'PriorDefault', 'Employed', 'CreditScore',
#        'DriversLicense', 'Citizen', 'ZipCode', 'Income', 'Approved',
#        'AgeLevel', 'DebtLevel', 'YearsEmployedLevel', 'CreditScoreLevel',
#        'IncomeLevel', 'TotalSavings', 'TotalSavingsLevel', 'ZipArea',
#        'Enc_Gender', 'Enc_Married', 'Enc_BankCustomer', 'Enc_EducationLevel',
#        'Enc_Ethnicity', 'Enc_PriorDefault', 'Enc_Employed',
#        'Enc_DriversLicense', 'Enc_Citizen', 'Enc_ZipCode', 'Enc_Approved',
#        'Enc_AgeLevel', 'Enc_DebtLevel', 'Enc_YearsEmployedLevel',
#        'Enc_CreditScoreLevel', 'Enc_IncomeLevel', 'Enc_TotalSavingsLevel',
#        'Enc_ZipArea'],
#       dtype='object')

# %%
X = data[['Age','Debt','YearsEmployed', 'CreditScore','Income','TotalSavings',
          'Enc_Gender', 'Enc_Married', 'Enc_BankCustomer', 'Enc_EducationLevel',
          'Enc_Ethnicity', 'Enc_PriorDefault', 'Enc_Employed','Enc_DriversLicense',
          'Enc_Citizen', 'Enc_ZipCode', 'Enc_AgeLevel', 'Enc_DebtLevel', 'Enc_YearsEmployedLevel',
          'Enc_CreditScoreLevel', 'Enc_IncomeLevel', 'Enc_TotalSavingsLevel','Enc_ZipArea']]
y = data['Enc_Approved']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25 , random_state = 44 , shuffle = True)

X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((498, 23), (167, 23), (498,), (167,))

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis,QuadraticDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report

# %%
GaussianNBModel = GaussianNB()
MultinomialNBModel = MultinomialNB(alpha=1.0)
BernoulliNBModel = BernoulliNB(alpha=1.0,binarize=1)
LogisticRegressionModel = LogisticRegression(penalty='l2',solver='sag',C=1.0,random_state=33)
SGDClassifierModel = SGDClassifier(penalty='l2',loss='squared_loss',learning_rate='optimal',random_state=33)
RandomForestClassifierModel = RandomForestClassifier(criterion = 'gini',n_estimators=300,max_depth=7,random_state=33) 
GBCModel = GradientBoostingClassifier(n_estimators=100,max_depth=3,random_state=33) 
QDAModel = QuadraticDiscriminantAnalysis(tol=0.0001)
SVCModel = SVC(kernel= 'rbf',max_iter=100,C=1.0,gamma='auto')
DecisionTreeClassifierModel = DecisionTreeClassifier(criterion='gini',max_depth=3,random_state=33)
KNNClassifierModel = KNeighborsClassifier(n_neighbors= 5,weights ='uniform',algorithm='auto') 

Models = [GaussianNBModel,KNNClassifierModel,MultinomialNBModel,
          BernoulliNBModel,LogisticRegressionModel,RandomForestClassifierModel,
          GBCModel,SGDClassifierModel,QDAModel,SVCModel,DecisionTreeClassifierModel]

# %%
ModelsScore = {}
for Model in Models : 
    print(f'for Model {str(Model).split("(")[0]}')
    Model.fit(X_train, y_train)
    print(f'Train Score is : {Model.score(X_train, y_train)}')
    print(f'Test Score is : {Model.score(X_test, y_test)}')
    y_pred = Model.predict(X_test)
    ClassificationReport = classification_report(y_test,y_pred)
    print('Classification Report is : \n', ClassificationReport )
    print(f'Precision value is  : {ClassificationReport.split()[19]}')
    print(f'Recall value is  : {ClassificationReport.split()[20]}')
    print(f'F1 Score value is  : {ClassificationReport.split()[21]}')
    ModelsScore[str(Model).split("(")[0]] = [ClassificationReport.split()[19],
                                             ClassificationReport.split()[20],ClassificationReport.split()[21]]
    print('=================================================')
# Out:
# for Model GaussianNB
# Train Score is : 0.7188755020080321
# Test Score is : 0.7005988023952096
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.82      0.34      0.48        68
#            1       0.68      0.95      0.79        99
#
#     accuracy                           0.70       167
#    macro avg       0.75      0.64      0.63       167
# weighted avg       0.74      0.70      0.66       167
#
# Precision value is  : 0.75
# Recall value is  : 0.64
# F1 Score value is  : 0.63
# =================================================
# for Model KNeighborsClassifier
# Train Score is : 0.8072289156626506
# Test Score is : 0.7365269461077845
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.69      0.63      0.66        68
#            1       0.76      0.81      0.78        99
#
#     accuracy                           0.74       167
#    macro avg       0.73      0.72      0.72       167
# weighted avg       0.73      0.74      0.73       167
#
# Precision value is  : 0.73
# Recall value is  : 0.72
# F1 Score value is  : 0.72
# =================================================
# for Model MultinomialNB
# Train Score is : 0.7028112449799196
# Test Score is : 0.7125748502994012
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.37      0.51        68
#            1       0.69      0.95      0.80        99
#
#     accuracy                           0.71       167
#    macro avg       0.76      0.66      0.65       167
# weighted avg       0.75      0.71      0.68       167
#
# Precision value is  : 0.76
# Recall value is  : 0.66
# F1 Score value is  : 0.65
# =================================================
# for Model BernoulliNB
# Train Score is : 0.7269076305220884
# Test Score is : 0.7964071856287425
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74        68
#            1       0.81      0.86      0.83        99
#
#     accuracy                           0.80       167
#    macro avg       0.79      0.78      0.79       167
# weighted avg       0.80      0.80      0.79       167
#
# Precision value is  : 0.79
# Recall value is  : 0.78
# F1 Score value is  : 0.79
# =================================================
# for Model LogisticRegression
# C:\Users\abdal\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Train Score is : 0.5662650602409639
# Test Score is : 0.5748502994011976
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.48      0.66      0.56        68
#            1       0.69      0.52      0.59        99
#
#     accuracy                           0.57       167
#    macro avg       0.59      0.59      0.57       167
# weighted avg       0.61      0.57      0.58       167
#
# Precision value is  : 0.59
# Recall value is  : 0.59
# F1 Score value is  : 0.57
# =================================================
# for Model RandomForestClassifier
# Train Score is : 0.963855421686747
# Test Score is : 0.9161676646706587
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        68
#            1       0.93      0.93      0.93        99
#
#     accuracy                           0.92       167
#    macro avg       0.91      0.91      0.91       167
# weighted avg       0.92      0.92      0.92       167
#
# Precision value is  : 0.91
# Recall value is  : 0.91
# F1 Score value is  : 0.91
# =================================================
# for Model GradientBoostingClassifier
# Train Score is : 0.9779116465863453
# Test Score is : 0.8862275449101796
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        68
#            1       0.92      0.89      0.90        99
#
#     accuracy                           0.89       167
#    macro avg       0.88      0.89      0.88       167
# weighted avg       0.89      0.89      0.89       167
#
# Precision value is  : 0.88
# Recall value is  : 0.89
# F1 Score value is  : 0.88
# =================================================
# for Model SGDClassifier
# Train Score is : 0.4598393574297189
# Test Score is : 0.41317365269461076
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58        68
#            1       1.00      0.01      0.02        99
#
#     accuracy                           0.41       167
#    macro avg       0.70      0.51      0.30       167
# weighted avg       0.76      0.41      0.25       167
#
# Precision value is  : 0.70
# Recall value is  : 0.51
# F1 Score value is  : 0.30
# =================================================
# for Model QuadraticDiscriminantAnalysis
# C:\Users\abdal\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:165: FutureWarning: The loss 'squared_loss' was deprecated in v1.0 and will be removed in version 1.2. Use `loss='squared_error'` which is equivalent.
#   warnings.warn(
# Train Score is : 0.6746987951807228
# Test Score is : 0.6766467065868264
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.59      0.66      0.62        68
#            1       0.75      0.69      0.72        99
#
#     accuracy                           0.68       167
#    macro avg       0.67      0.67      0.67       167
# weighted avg       0.68      0.68      0.68       167
#
# Precision value is  : 0.67
# Recall value is  : 0.67
# F1 Score value is  : 0.67
# =================================================
# for Model SVC
# Train Score is : 0.7831325301204819
# Test Score is : 0.5089820359281437
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.34      0.22      0.27        68
#            1       0.57      0.71      0.63        99
#
#     accuracy                           0.51       167
#    macro avg       0.46      0.46      0.45       167
# weighted avg       0.48      0.51      0.48       167
#
# Precision value is  : 0.46
# Recall value is  : 0.46
# F1 Score value is  : 0.45
# =================================================
# for Model DecisionTreeClassifier
# Train Score is : 0.8634538152610441
# Test Score is : 0.8622754491017964
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85        68
#            1       0.96      0.80      0.87        99
#
#     accuracy                           0.86       167
#    macro avg       0.86      0.88      0.86       167
# weighted avg       0.88      0.86      0.86       167
#
# Precision value is  : 0.86
# Recall value is  : 0.88
# F1 Score value is  : 0.86
# =================================================
# C:\Users\abdal\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\abdal\anaconda3\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
ModelsScore
# Out:
# {'GaussianNB': ['0.75', '0.64', '0.63'],
#  'KNeighborsClassifier': ['0.73', '0.72', '0.72'],
#  'MultinomialNB': ['0.76', '0.66', '0.65'],
#  'BernoulliNB': ['0.79', '0.78', '0.79'],
#  'LogisticRegression': ['0.59', '0.59', '0.57'],
#  'RandomForestClassifier': ['0.91', '0.91', '0.91'],
#  'GradientBoostingClassifier': ['0.88', '0.89', '0.88'],
#  'SGDClassifier': ['0.70', '0.51', '0.30'],
#  'QuadraticDiscriminantAnalysis': ['0.67', '0.67', '0.67'],
#  'SVC': ['0.46', '0.46', '0.45'],
#  'DecisionTreeClassifier': ['0.86', '0.88', '0.86']}

# %%
Model = RandomForestClassifierModel
Model.fit(X_train, y_train)
print(f'Train Score is : {Model.score(X_train, y_train)}')
print(f'Test Score is : {Model.score(X_test, y_test)}')
y_pred = Model.predict(X_test)
ClassificationReport = classification_report(y_test,y_pred)
print('Classification Report is : \n', ClassificationReport )
print(f'Precision value is  : {ClassificationReport.split()[19]}')
print(f'Recall value is  : {ClassificationReport.split()[20]}')
print(f'F1 Score value is  : {ClassificationReport.split()[21]}')
# Out:
# Train Score is : 0.963855421686747
# Test Score is : 0.9161676646706587
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        68
#            1       0.93      0.93      0.93        99
#
#     accuracy                           0.92       167
#    macro avg       0.91      0.91      0.91       167
# weighted avg       0.92      0.92      0.92       167
#
# Precision value is  : 0.91
# Recall value is  : 0.91
# F1 Score value is  : 0.91

# %%
from sklearn.metrics import confusion_matrix

CM = confusion_matrix(y_test, y_pred)
print('Confusion Matrix is : \n', CM)
# Out:
# Confusion Matrix is :
#  [[61  7]
#  [ 7 92]]

# %%
sns.heatmap(CM, center = True,cmap='Blues_r')
plt.show()

# %%
AllPredict = Model.predict(X)
ClassificationReport = classification_report(y,AllPredict)
print('Classification Report is : \n', ClassificationReport )
print(f'Precision value is  : {ClassificationReport.split()[19]}')
print(f'Recall value is  : {ClassificationReport.split()[20]}')
print(f'F1 Score value is  : {ClassificationReport.split()[21]}')
# Out:
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95       298
#            1       0.94      0.97      0.96       367
#
#     accuracy                           0.95       665
#    macro avg       0.95      0.95      0.95       665
# weighted avg       0.95      0.95      0.95       665
#
# Precision value is  : 0.95
# Recall value is  : 0.95
# F1 Score value is  : 0.95

# %%
data['Predicted Value'] = AllPredict
data
# Out:
#     Gender    Age    Debt Married BankCustomer EducationLevel Ethnicity  \
# 0        b  30.83   0.000       u            g              w         v
# 1        a  58.67   4.460       u            g              q         h
# 2        a  24.50   0.500       u            g              q         h
# 3        b  27.83   1.540       u            g              w         v
# 4        b  20.17   5.625       u            g              w         v
# ..     ...    ...     ...     ...          ...            ...       ...
# 660      b  21.08  10.085       y            p              e         h
# 661      a  22.67   0.750       u            g              c         v
# 662      a  25.25  13.500       y            p             ff        ff
# 663      b  17.92   0.205       u            g             aa         v
# 664      b  35.00   3.375       u            g              c         h
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0             1.25            t        t            1              f       g
# 1             3.04            t        t            6              f       g
# 2             1.50            t        f            0              f       g
# 3             3.75            t        t            5              t       g
# 4             1.71            t        f            0              f       s
# ..             ...          ...      ...          ...            ...     ...
# 660           1.25            f        f            0              f       g
# 661           2.00            f        t            2              t       g
# 662           2.00            f        t            1              t       g
# 663           0.04            f        f            0              f       g
# 664           8.29            f        f            0              t       g
#
#     ZipCode  Income Approved  AgeLevel    DebtLevel YearsEmployedLevel  \
# 0     00202       0        +     Adult    Poor Debt  Medium Experience
# 1     00043     560        +       Old    Poor Debt  Medium Experience
# 2     00280     824        +     Adult    Poor Debt  Medium Experience
# 3     00100       3        +     Adult    Poor Debt  Medium Experience
# 4     00120       0        +  YoungMan  Medium Debt  Medium Experience
# ..      ...     ...      ...       ...          ...                ...
# 660   00260       0        -  YoungMan  Medium Debt  Medium Experience
# 661   00200     394        -     Adult    Poor Debt  Medium Experience
# 662   00200       1        -     Adult  Medium Debt  Medium Experience
# 663   00280     750        -      Teen    Poor Debt     Low Experience
# 664   00000       0        -     Adult    Poor Debt    Good Experience
#
#     CreditScoreLevel    IncomeLevel  TotalSavings TotalSavingsLevel ZipArea  \
# 0        Poor Credit    Poor Income          0.00        No Savings  Area 8
# 1      Medium Credit  Medium Income       5107.20       Low Savings  Area 2
# 2        Poor Credit  Medium Income       3708.00       Low Savings  Area 8
# 3      Medium Credit    Poor Income         33.75        No Savings  Area 7
# 4        Poor Credit    Poor Income          0.00        No Savings  Area 7
# ..               ...            ...           ...               ...     ...
# 660      Poor Credit    Poor Income          0.00        No Savings  Area 8
# 661      Poor Credit  Medium Income       2364.00       Low Savings  Area 8
# 662      Poor Credit    Poor Income          6.00        No Savings  Area 8
# 663      Poor Credit  Medium Income         90.00        No Savings  Area 8
# 664      Poor Credit    Poor Income          0.00        No Savings  Area 2
#
#      Enc_Gender  Enc_Married  Enc_BankCustomer  Enc_EducationLevel  \
# 0             1            1                 0                  12
# 1             0            1                 0                  10
# 2             0            1                 0                  10
# 3             1            1                 0                  12
# 4             1            1                 0                  12
# ..          ...          ...               ...                 ...
# 660           1            2                 2                   4
# 661           0            1                 0                   1
# 662           0            2                 2                   5
# 663           1            1                 0                   0
# 664           1            1                 0                   1
#
#      Enc_Ethnicity  Enc_PriorDefault  Enc_Employed  Enc_DriversLicense  \
# 0                7                 1             1                   0
# 1                3                 1             1                   0
# 2                3                 1             0                   0
# 3                7                 1             1                   1
# 4                7                 1             0                   0
# ..             ...               ...           ...                 ...
# 660              3                 0             0                   0
# 661              7                 0             1                   1
# 662              2                 0             1                   1
# 663              7                 0             0                   0
# 664              3                 0             0                   1
#
#      Enc_Citizen  Enc_ZipCode  Enc_Approved  Enc_AgeLevel  Enc_DebtLevel  \
# 0              0           68             0             0              2
# 1              0           11             0             1              2
# 2              0           94             0             0              2
# 3              0           31             0             0              2
# 4              2           37             0             3              1
# ..           ...          ...           ...           ...            ...
# 660            0           89             1             3              1
# 661            0           67             1             0              2
# 662            0           67             1             0              1
# 663            0           94             1             2              2
# 664            0            0             1             0              2
#
#      Enc_YearsEmployedLevel  Enc_CreditScoreLevel  Enc_IncomeLevel  \
# 0                         2                     2                2
# 1                         2                     1                1
# 2                         2                     2                1
# 3                         2                     1                2
# 4                         2                     2                2
# ..                      ...                   ...              ...
# 660                       2                     2                2
# 661                       2                     2                1
# 662                       2                     2                2
# 663                       1                     2                1
# 664                       0                     2                2
#
#      Enc_TotalSavingsLevel  Enc_ZipArea  Predicted Value
# 0                        3            9                0
# 1                        1            3                0
# 2                        1            9                0
# 3                        3            8                0
# 4                        3            8                0
# ..                     ...          ...              ...
# 660                      3            9                1
# 661                      1            9                1
# 662                      3            9                1
# 663                      3            9                1
# 664                      3            3                1
#
# [665 rows x 43 columns]

# %%
ValuesDict = {0:'Approved',1:'Not Approved'}
WrongIndices = []
WrongCounter = 0
Index = -1
for Actual,Predicted in zip(data['Enc_Approved'].tolist(),data['Predicted Value'].tolist()) : 
    Index+=1
    if Actual != Predicted : 
        WrongCounter+=1
        WrongIndices.append(Index)
        print(f'Wrong Prediction at Index {Index} predicted as {ValuesDict[Predicted]} while it should be {ValuesDict[Actual]}')
print(f'\n\n Total Wrong Predictions is {WrongCounter} out of total {data.shape[0]} with percentage {np.round(100*(data.shape[0]-WrongCounter)/data.shape[0],2)}%')
# Out:
# Wrong Prediction at Index 5 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 10 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 21 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 48 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 49 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 50 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 71 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 74 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 98 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 103 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 107 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 109 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 113 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 114 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 162 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 168 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 169 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 176 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 222 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 224 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 264 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 312 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 313 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 314 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 315 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 505 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 523 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 526 predicted as Approved while it should be Not Approved
# Wrong Prediction at Index 567 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 574 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 576 predicted as Not Approved while it should be Approved
# Wrong Prediction at Index 585 predicted as Not Approved while it should be Approved
#
#
#  Total Wrong Predictions is 32 out of total 665 with percentage 95.19%

# %%
data.iloc[WrongIndices,:]
# Out:
#     Gender    Age    Debt Married BankCustomer EducationLevel Ethnicity  \
# 5        b  32.08   4.000       u            g              m         v
# 10       b  22.08   0.830       u            g              c         h
# 21       b  23.25   1.000       u            g              c         v
# 48       b  41.50   1.540       u            g              i        bb
# 49       b  23.92   0.665       u            g              c         v
# 50       a  25.75   0.500       u            g              c         h
# 71       a  38.58   5.000       u            g             cc         v
# 74       b  20.67   5.290       u            g              q         v
# 98       a  28.50   1.000       u            g              q         v
# 103      b  27.83   4.000       y            p              i         h
# 107      b  40.92   2.250       y            p              x         h
# 109      b  29.17   3.500       u            g              w         v
# 113      b  20.67   1.250       y            p              c         h
# 114      a  25.42   1.125       u            g              q         v
# 162      b  32.00   1.750       y            p              e         h
# 168      b  37.50   1.125       y            p              d         v
# 169      a  25.08   2.540       y            p             aa         v
# 176      a  26.08   8.665       u            g             aa         v
# 222      b  23.25   4.000       u            g              c        bb
# 224      a  22.50   8.460       y            p              x         v
# 264      b  18.00   0.165       u            g              q         n
# 312      b  36.75   0.125       y            p              c         v
# 313      b  21.25   1.500       u            g              w         v
# 314      a  18.08   0.375       l           gg             cc        ff
# 315      a  33.67   0.375       u            g             cc         v
# 505      a  22.50   8.500       u            g              q         v
# 523      b  42.75   3.000       u            g              i        bb
# 526      b  30.08   1.040       y            p              i        bb
# 567      b  73.42  17.750       u            g             ff        ff
# 574      b  34.17   5.250       u            g              w         v
# 576      b  25.75   0.750       u            g              c        bb
# 585      b  16.17   0.040       u            g              c         v
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 5            2.500            t        f            0              t       g
# 10           2.165            f        f            0              t       g
# 21           0.835            t        f            0              f       s
# 48           3.500            f        f            0              f       g
# 49           0.165            f        f            0              f       g
# 50           0.875            t        f            0              t       g
# 71          13.500            t        f            0              t       g
# 74           0.375            t        t            1              f       g
# 98           1.000            t        t            2              t       g
# 103          5.750            t        t            2              t       g
# 107         10.000            t        f            0              t       g
# 109          3.500            t        t            3              t       g
# 113          1.375            t        t            3              t       g
# 114          1.290            t        t            2              f       g
# 162          0.040            t        f            0              t       g
